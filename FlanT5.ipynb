# %%
from transformers import AutoTokenizer, AutoModel , AutoModelForTokenClassification, pipeline , TFAutoModelForSequenceClassification ,TFAutoModelForSeq2SeqLM
model_name = "d4data/biomedical-ner-all"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

# %%
nlp = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# Input sentence
text = "I have sore-throat and fever"

# Run NER
entities = nlp(text)
# Out:
# Device set to use cpu

# %%
for entity in entities:
    print(f"Word: {entity['word']}, Entity: {entity['entity_group']}")
# Out:
# Word: sore, Entity: Sign_symptom
# Word: throat, Entity: Biological_structure
# Word: fever, Entity: Sign_symptom

# %%
symptoms_user = [ent['word'] for ent in entities if ent['entity_group'] == "Sign_symptom" or ent['entity_group'] == "Biological_structure"]

print("Extracted symptoms:", symptoms_user)
# Out:
# Extracted symptoms: ['sore', 'throat', 'fever']

# %%
import json
with open('symptoms.json', 'r') as file:
    data = json.load(file)

# %%
def get_word (words):
    new = []
    for word in words :
        for w in word.split('_'):
            new.append(w)
    return new

# %%
diseases = {}
for disease in data['diseases'] :
    symptom_list = get_word(disease['symptoms'])
    if all(item in symptom_list  for item in symptoms_user):
        diseases[disease['disease_name']] = disease['symptoms']
print (diseases)
# Out:
# {'influenza': ['fever', 'cough', 'sore_throat', 'runny_or_stuffy_nose', 'muscle_aches', 'headache', 'fatigue', 'chills', 'sweats'], 'common_cold': ['runny_or_stuffy_nose', 'sneezing', 'sore_throat', 'cough', 'mild_fatigue', 'low-grade_fever', 'headache'], 'covid_19': ['fever', 'cough', 'shortness_of_breath', 'fatigue', 'muscle_or_body_aches', 'headache', 'new_loss_of_taste_or_smell', 'sore_throat', 'congestion_or_runny_nose', 'nausea_or_vomiting', 'diarrhea']}

# %%
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-large")
model = TFAutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-large")

def get_general_response(prompt):
    inputs = tokenizer(prompt, return_tensors="tf", max_length=512, truncation=True, padding=True)
    outputs = model.generate(inputs["input_ids"], max_length=150, num_beams=5, early_stopping=True)
    
    return tokenizer.decode(outputs[0], skip_special_tokens=True)
# Out:
# All PyTorch model weights were used when initializing TFT5ForConditionalGeneration.
#
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %%
prompt = 'user says : Hi my name is Mehrdad what is your name ?'
get_general_response(prompt)
# Out:
# 'Mehrdad'

# %%
symptom_to_diseases = {}
for entry in data["diseases"]:
    disease = entry["disease_name"]
    for symptom in entry["symptoms"]:
        symptom_to_diseases.setdefault(symptom, set()).add(disease)

# %%
symptom_to_diseases
# Out:
# {'itching': {'allergy',
#   'chronic_cholestasis',
#   'drug_reaction',
#   'fungal_infection',
#   'hepatitis_a',
#   'hepatitis_b',
#   'hepatitis_c',
#   'impetigo',
#   'jaundice',
#   'liver_cirrhosis',
#   'psoriasis'},
#  'skin_rash': {'aids',
#   'allergy',
#   'drug_reaction',
#   'fungal_infection',
#   'impetigo',
#   'lupus',
#   'measles'},
#  'nodular_lesions': {'fungal_infection'},
#  'skin_eruptions': {'fungal_infection'},
#  'discolored_patches': {'fungal_infection'},
#  'scaling': {'fungal_infection'},
#  'redness': {'fungal_infection', 'gout'},
#  'cracked_skin': {'fungal_infection'},
#  'peeling_skin': {'fungal_infection'},
#  'sneezing': {'allergy', 'common_cold'},
#  'runny_nose': {'allergy', 'measles'},
#  'nasal_congestion': {'allergy'},
#  'itchy_eyes': {'allergy'},
#  'watery_eyes': {'allergy'},
#  'hives': {'allergy', 'drug_reaction'},
#  'swelling': {'allergy', 'drug_reaction', 'gout'},
#  'shortness_of_breath': {'aids',
#   'allergy',
#   'anemia',
#   'arrhythmia',
#   'bronchial_asthma',
#   'chronic_obstructive_pulmonary_disease',
#   'congestive_heart_failure',
#   'coronary_artery_disease',
#   'covid_19',
#   'drug_reaction',
#   'hypertension',
#   'pneumonia'},
#  'wheezing': {'allergy',
#   'bronchial_asthma',
#   'chronic_obstructive_pulmonary_disease',
#   'drug_reaction'},
#  'coughing': {'allergy', 'bronchial_asthma'},
#  'red_eyes': {'allergy', 'measles'},
#  'heartburn': {'GERD', 'peptic_ulcer_disease'},
#  'chest_pain': {'GERD',
#   'anemia',
#   'congestive_heart_failure',
#   'coronary_artery_disease',
#   'hypertension',
#   'lupus',
#   'pneumonia',
#   'tuberculosis'},
#  'regurgitation': {'GERD'},
#  'acidic_taste_in_mouth': {'GERD'},
#  'difficulty_swallowing': {'GERD', 'paralysis_(brain_hemorrhage)'},
#  'chronic_cough': {'GERD', 'chronic_obstructive_pulmonary_disease'},
#  'sore_throat': {'GERD', 'common_cold', 'covid_19', 'influenza'},
#  'hoarseness': {'GERD', 'hypothyroidism'},
#  'sensation_of_lump_in_throat': {'GERD'},
#  'nausea': {'GERD',
#   'addison_disease',
#   'appendicitis',
#   'chronic_cholestasis',
#   'coronary_artery_disease',
#   'dengue',
#   'drug_reaction',
#   'gallstones',
#   'gastroenteritis',
#   'hepatitis_a',
#   'hepatitis_b',
#   'hepatitis_c',
#   'hepatitis_e',
#   'jaundice',
#   'kidney_stones',
#   'liver_cirrhosis',
#   'malaria',
#   'meningitis',
#   'migraine',
#   'pancreatitis',
#   'peptic_ulcer_disease',
#   'pneumonia',
#   'typhoid'},
#  'bad_breath': {'GERD'},
#  'fatigue': {'addison_disease',
#   'anemia',
#   'anxiety_disorder',
#   'arrhythmia',
#   'arthritis',
#   'bronchial_asthma',
#   'chronic_cholestasis',
#   'chronic_obstructive_pulmonary_disease',
#   'congestive_heart_failure',
#   'coronary_artery_disease',
#   'covid_19',
#   'dengue',
#   'depression',
#   'diabetes_mellitus',
#   'drug_reaction',
#   'fibromyalgia',
#   'hepatitis_a',
#   'hepatitis_b',
#   'hepatitis_c',
#   'hepatitis_e',
#   'hypertension',
#   'hyperthyroidism',
#   'hypothyroidism',
#   'influenza',
#   'jaundice',
#   'liver_cirrhosis',
#   'lupus',
#   'malaria',
#   'migraine',
#   'multiple_sclerosis',
#   'pneumonia',
#   'rheumatoid_arthritis',
#   'tuberculosis',
#   'typhoid'},
#  'jaundice': {'chronic_cholestasis',
#   'gallstones',
#   'hepatitis_a',
#   'hepatitis_b',
#   'hepatitis_c',
#   'hepatitis_e',
#   'liver_cirrhosis',
#   'malaria'},
#  'dark_urine': {'chronic_cholestasis',
#   'hepatitis_a',
#   'hepatitis_b',
#   'hepatitis_c',
#   'hepatitis_e',
#   'jaundice'},
#  'pale_stools': {'chronic_cholestasis', 'jaundice'},
#  'abdominal_pain': {'addison_disease',
#   'appendicitis',
#   'chronic_cholestasis',
#   'dengue',
#   'drug_reaction',
#   'gastroenteritis',
#   'hepatitis_a',
#   'hepatitis_b',
#   'hepatitis_c',
#   'hepatitis_e',
#   'jaundice',
#   'malaria',
#   'typhoid'},
#  'loss_of_appetite': {'appendicitis',
#   'chickenpox',
#   'chronic_cholestasis',
#   'gastroenteritis',
#   'hepatitis_a',
#   'hepatitis_b',
#   'hepatitis_c',
#   'hepatitis_e',
#   'jaundice',
#   'liver_cirrhosis',
#   'mumps',
#   'peptic_ulcer_disease',
#   'rheumatoid_arthritis',
#   'tuberculosis',
#   'typhoid'},
#  'weight_loss': {'addison_disease',
#   'chronic_cholestasis',
#   'hyperthyroidism',
#   'jaundice',
#   'peptic_ulcer_disease',
#   'tuberculosis'},
#  'dry_skin': {'chronic_cholestasis', 'hypothyroidism', 'psoriasis'},
#  'bone_pain': {'chronic_cholestasis'},
#  'fever': {'aids',
#   'appendicitis',
#   'chickenpox',
#   'covid_19',
#   'drug_reaction',
#   'gallstones',
#   'gastroenteritis',
#   'hepatitis_a',
#   'hepatitis_b',
#   'hepatitis_c',
#   'hepatitis_e',
#   'influenza',
#   'lupus',
#   'malaria',
#   'meningitis',
#   'mumps',
#   'pancreatitis',
#   'pneumonia',
#   'rheumatoid_arthritis',
#   'tuberculosis',
#   'urinary_tract_infection'},
#  'chills': {'drug_reaction', 'influenza', 'malaria'},
#  'vomiting': {'appendicitis',
#   'dengue',
#   'drug_reaction',
#   'gallstones',
#   'gastroenteritis',
#   'hepatitis_a',
#   'hepatitis_b',
#   'hepatitis_c',
#   'hepatitis_e',
#   'jaundice',
#   'kidney_stones',
#   'malaria',
#   'meningitis',
#   'migraine',
#   'pancreatitis',
#   'peptic_ulcer_disease',
#   'pneumonia',
#   'typhoid'},
#  'joint_pain': {'arthritis',
#   'drug_reaction',
#   'hepatitis_b',
#   'hepatitis_c',
#   'lupus',
#   'rheumatoid_arthritis',
#   'rubella'},
#  'yellowing_of_skin_or_eyes': {'drug_reaction'},
#  'eosinophilia': {'drug_reaction'},
#  'anaphylaxis': {'drug_reaction'},
#  'burning_stomach_pain': {'peptic_ulcer_disease'},
#  'bloating': {'gastroenteritis', 'peptic_ulcer_disease'},
#  'indigestion': {'peptic_ulcer_disease'},
#  'bloody_or_black_stools': {'peptic_ulcer_disease'},
#  'feeling_of_fullness': {'peptic_ulcer_disease'},
#  'belching': {'peptic_ulcer_disease'},
#  'gastritis': {'peptic_ulcer_disease'},
#  'anemia': {'malaria', 'peptic_ulcer_disease'},
#  'unexplained_weight_loss': {'aids', 'diabetes_mellitus'},
#  'night_sweats': {'aids', 'tuberculosis'},
#  'chronic_fatigue': {'aids'},
#  'swollen_lymph_nodes': {'aids', 'impetigo', 'rubella'},
#  'frequent_infections': {'aids', 'diabetes_mellitus'},
#  'diarrhea': {'aids', 'covid_19', 'dengue', 'gastroenteritis', 'malaria'},
#  'persistent_cough': {'aids', 'congestive_heart_failure', 'tuberculosis'},
#  'oral_candidiasis': {'aids'},
#  'pneumonia': {'aids'},
#  'lesions_in_mouth_or_genitals': {'aids'},
#  'neurological_symptoms': {'aids'},
#  'memory_loss': {'aids', 'alzheimers_disease'},
#  'confusion': {'aids',
#   'liver_cirrhosis',
#   'meningitis',
#   'paralysis_(brain_hemorrhage)',
#   'pneumonia',
#   'stroke'},
#  'cramps': {'gastroenteritis'},
#  'headache': {'anemia',
#   'chickenpox',
#   'common_cold',
#   'covid_19',
#   'gastroenteritis',
#   'hypertension',
#   'influenza',
#   'malaria',
#   'mumps',
#   'rubella',
#   'typhoid'},
#  'dehydration': {'gastroenteritis'},
#  'bloody_stools': {'gastroenteritis'},
#  'chest_tightness': {'bronchial_asthma',
#   'chronic_obstructive_pulmonary_disease'},
#  'difficulty_breathing': {'bronchial_asthma', 'paralysis_(brain_hemorrhage)'},
#  'rapid_breathing': {'bronchial_asthma', 'pneumonia'},
#  'difficulty_talking': {'bronchial_asthma'},
#  'sweating': {'bronchial_asthma',
#   'coronary_artery_disease',
#   'hyperthyroidism',
#   'malaria',
#   'pneumonia',
#   'typhoid'},
#  'restlessness': {'anxiety_disorder', 'bronchial_asthma'},
#  'severe_headache': {'dengue',
#   'meningitis',
#   'migraine',
#   'paralysis_(brain_hemorrhage)',
#   'stroke'},
#  'sensitivity_to_light': {'meningitis', 'migraine'},
#  'sensitivity_to_sound': {'migraine'},
#  'blurred_vision': {'diabetes_mellitus', 'migraine'},
#  'aura': {'epilepsy', 'migraine'},
#  'throbbing_pain': {'migraine'},
#  'unilateral_headache': {'migraine'},
#  'dizziness': {'anemia',
#   'arrhythmia',
#   'coronary_artery_disease',
#   'hypertension',
#   'migraine',
#   'multiple_sclerosis',
#   'paralysis_(brain_hemorrhage)',
#   'stroke'},
#  'difficulty_concentrating': {'anxiety_disorder', 'depression', 'migraine'},
#  'neck_pain': {'cervical_spondylosis'},
#  'stiffness_in_neck': {'cervical_spondylosis'},
#  'headaches': {'cervical_spondylosis'},
#  'shoulder_pain': {'cervical_spondylosis'},
#  'numbness_or_tingling_in_arms': {'cervical_spondylosis'},
#  'muscle_weakness': {'arthritis',
#   'cervical_spondylosis',
#   'cushing_syndrome',
#   'multiple_sclerosis'},
#  'loss_of_balance': {'cervical_spondylosis',
#   'paralysis_(brain_hemorrhage)',
#   'stroke'},
#  'radiating_pain_in_arms_or_hands': {'cervical_spondylosis'},
#  'reduced_range_of_motion_in_neck': {'cervical_spondylosis'},
#  'pain_when_turning_head': {'cervical_spondylosis'},
#  'sudden_loss_of_movement': {'paralysis_(brain_hemorrhage)'},
#  'weakness_on_one_side_of_body': {'paralysis_(brain_hemorrhage)'},
#  'numbness': {'paralysis_(brain_hemorrhage)'},
#  'vision_problems': {'multiple_sclerosis',
#   'paralysis_(brain_hemorrhage)',
#   'stroke'},
#  'difficulty_speaking': {'paralysis_(brain_hemorrhage)'},
#  'seizures': {'meningitis', 'paralysis_(brain_hemorrhage)'},
#  'neck_stiffness': {'paralysis_(brain_hemorrhage)'},
#  'yellowing_of_skin': {'jaundice'},
#  'yellowing_of_eyes': {'jaundice'},
#  'swelling_in_legs_or_abdomen': {'hepatitis_c', 'jaundice'},
#  'muscle_pain': {'malaria'},
#  'cough': {'common_cold',
#   'covid_19',
#   'influenza',
#   'malaria',
#   'measles',
#   'pneumonia'},
#  'high_fever': {'dengue', 'measles', 'typhoid'},
#  'pain_behind_eyes': {'dengue'},
#  'muscle_and_joint_pain': {'dengue', 'hepatitis_a'},
#  'rash': {'dengue', 'rubella', 'typhoid'},
#  'skin_bleeding': {'dengue'},
#  'nosebleeds': {'dengue', 'hypertension'},
#  'gum_bleeding': {'dengue'},
#  'low_white_blood_cell_count': {'dengue'},
#  'weakness': {'anemia', 'typhoid'},
#  'diarrhea_or_constipation': {'typhoid'},
#  'dry_cough': {'typhoid'},
#  'enlarged_spleen_or_liver': {'typhoid'},
#  'light_colored_stools': {'hepatitis_a',
#   'hepatitis_b',
#   'hepatitis_c',
#   'hepatitis_e'},
#  'muscle_aches': {'hepatitis_b',
#   'hepatitis_c',
#   'influenza',
#   'mumps',
#   'pneumonia'},
#  'elevated_liver_enzyme_levels': {'hepatitis_c'},
#  'shaking_chills': {'pneumonia'},
#  'blue_tinged_skin': {'pneumonia'},
#  'swelling_in_joints': {'arthritis'},
#  'stiffness': {'arthritis'},
#  'reduced_range_of_motion': {'arthritis'},
#  'warmth_in_joints': {'arthritis'},
#  'redness_in_joints': {'arthritis', 'rheumatoid_arthritis'},
#  'tenderness_in_joints': {'arthritis'},
#  'difficulty_moving_joints': {'arthritis'},
#  'red_patchy_skin': {'psoriasis'},
#  'scaly_skin': {'psoriasis'},
#  'painful_skin': {'psoriasis'},
#  'cracked_skin_that_may_bleed': {'psoriasis'},
#  'swollen_joints': {'psoriasis'},
#  'thickened_nails': {'psoriasis'},
#  'flaking_scales_on_the_skin': {'psoriasis'},
#  'burning_sensation_on_skin': {'psoriasis'},
#  'red_sores': {'impetigo'},
#  'fluid_filled_blisters': {'impetigo'},
#  'honey_colored_crusts': {'impetigo'},
#  'painful_sores': {'impetigo'},
#  'spreading_skin_lesions': {'impetigo'},
#  'mild_fever': {'impetigo'},
#  'increased_thirst': {'diabetes_mellitus'},
#  'frequent_urination': {'diabetes_mellitus',
#   'kidney_stones',
#   'urinary_tract_infection'},
#  'extreme_hunger': {'diabetes_mellitus'},
#  'slow_healing_sores': {'diabetes_mellitus'},
#  'visual_disturbances': {'hypertension'},
#  'pain_in_arms_or_back': {'coronary_artery_disease'},
#  'sudden_numbness_or_weakness': {'stroke'},
#  'trouble_speaking_or_understanding': {'stroke'},
#  'coughing_up_blood': {'tuberculosis'},
#  'runny_or_stuffy_nose': {'common_cold', 'influenza'},
#  'sweats': {'influenza'},
#  'mild_fatigue': {'common_cold'},
#  'low-grade_fever': {'common_cold'},
#  'muscle_or_body_aches': {'covid_19'},
#  'new_loss_of_taste_or_smell': {'covid_19'},
#  'congestion_or_runny_nose': {'covid_19'},
#  'nausea_or_vomiting': {'covid_19'},
#  'frequent_respiratory_infections': {'chronic_obstructive_pulmonary_disease'},
#  'swelling_in_ankles_legs_or_feet': {'chronic_obstructive_pulmonary_disease'},
#  'recurrent_seizures': {'epilepsy'},
#  'loss_of_consciousness': {'epilepsy'},
#  'muscle_stiffness': {'epilepsy'},
#  'jerking_movements': {'epilepsy'},
#  'confusion_after_seizure': {'epilepsy'},
#  'staring_spells': {'epilepsy'},
#  'tremors': {'hyperthyroidism', 'parkinsons_disease'},
#  'muscle_rigidity': {'parkinsons_disease'},
#  'bradykinesia': {'parkinsons_disease'},
#  'postural_instability': {'parkinsons_disease'},
#  'slurred_speech': {'parkinsons_disease'},
#  'writing_changes': {'parkinsons_disease'},
#  'depression': {'fibromyalgia', 'hypothyroidism', 'parkinsons_disease'},
#  'sleep_disturbances': {'anxiety_disorder',
#   'bipolar_disorder',
#   'depression',
#   'fibromyalgia',
#   'parkinsons_disease'},
#  'difficulty_planning_or_solving_problems': {'alzheimers_disease'},
#  'confusion_with_time_or_place': {'alzheimers_disease'},
#  'trouble_understanding_visual_images': {'alzheimers_disease'},
#  'new_problems_with_words_in_speaking_or_writing': {'alzheimers_disease'},
#  'misplacing_things': {'alzheimers_disease'},
#  'decreased_judgment': {'alzheimers_disease'},
#  'withdrawal_from_work_or_social_activities': {'alzheimers_disease'},
#  'changes_in_mood_or_personality': {'alzheimers_disease'},
#  'persistent_sadness': {'depression'},
#  'loss_of_interest_in_activities': {'depression'},
#  'appetite_changes': {'depression'},
#  'feelings_of_worthlessness': {'depression'},
#  'thoughts_of_death_or_suicide': {'depression'},
#  'excessive_worry': {'anxiety_disorder'},
#  'irritability': {'anxiety_disorder', 'tension_headache'},
#  'muscle_tension': {'anxiety_disorder'},
#  'panic_attacks': {'anxiety_disorder'},
#  'extreme_mood_swings': {'bipolar_disorder'},
#  'manic_episodes': {'bipolar_disorder'},
#  'depressive_episodes': {'bipolar_disorder'},
#  'impulsive_behaviors': {'bipolar_disorder'},
#  'racing_thoughts': {'bipolar_disorder'},
#  'increased_activity_levels': {'bipolar_disorder'},
#  'weight_gain': {'cushing_syndrome',
#   'hypothyroidism',
#   'polycystic_ovary_syndrome'},
#  'cold_intolerance': {'hypothyroidism'},
#  'constipation': {'hypothyroidism'},
#  'slow_heart_rate': {'hypothyroidism'},
#  'memory_problems': {'hypothyroidism', 'multiple_sclerosis'},
#  'puffy_face': {'hypothyroidism'},
#  'rapid_heartbeat': {'hyperthyroidism', 'pancreatitis'},
#  'nervousness': {'hyperthyroidism'},
#  'heat_intolerance': {'hyperthyroidism'},
#  'frequent_bowel_movements': {'hyperthyroidism'},
#  'sleep_difficulty': {'hyperthyroidism'},
#  'goiter': {'hyperthyroidism'},
#  'hair_loss': {'lupus'},
#  'photosensitivity': {'lupus'},
#  'mouth_ulcers': {'lupus'},
#  'kidney_problems': {'lupus'},
#  'swelling_in_legs_or_eyes': {'lupus'},
#  'numbness_or_tingling': {'multiple_sclerosis'},
#  'balance_problems': {'multiple_sclerosis'},
#  'bladder_issues': {'multiple_sclerosis'},
#  'difficulty_walking': {'multiple_sclerosis'},
#  'joint_swelling': {'rheumatoid_arthritis'},
#  'morning_stiffness': {'rheumatoid_arthritis'},
#  'symmetrical_joint_involvement': {'rheumatoid_arthritis'},
#  'back_pain': {'osteoporosis'},
#  'loss_of_height': {'osteoporosis'},
#  'stooped_posture': {'osteoporosis'},
#  'easy_bone_fractures': {'osteoporosis'},
#  'brittle_bones': {'osteoporosis'},
#  'limited_mobility': {'osteoporosis'},
#  'pale_skin': {'anemia'},
#  'cold_hands_and_feet': {'anemia'},
#  'pain_in_lower_right_abdomen': {'appendicitis'},
#  'constipation_or_diarrhea': {'appendicitis'},
#  'abdominal_swelling': {'appendicitis', 'liver_cirrhosis'},
#  'burning_sensation_during_urination': {'urinary_tract_infection'},
#  'cloudy_urine': {'kidney_stones', 'urinary_tract_infection'},
#  'strong_urine_odor': {'urinary_tract_infection'},
#  'pelvic_pain': {'urinary_tract_infection'},
#  'blood_in_urine': {'kidney_stones', 'urinary_tract_infection'},
#  'lower_abdominal_pain': {'urinary_tract_infection'},
#  'severe_flank_pain': {'kidney_stones'},
#  'pain_during_urination': {'kidney_stones'},
#  'foul_smelling_urine': {'kidney_stones'},
#  'sudden_abdominal_pain': {'gallstones'},
#  'pain_in_right_upper_abdomen': {'gallstones'},
#  'back_pain_between_shoulders': {'gallstones'},
#  'pain_after_eating_fatty_foods': {'gallstones'},
#  'upper_abdominal_pain': {'pancreatitis'},
#  'abdominal_pain_that_radiates_to_back': {'pancreatitis'},
#  'swollen_abdomen': {'pancreatitis'},
#  'tenderness_in_abdomen': {'pancreatitis'},
#  'stiff_neck': {'meningitis'},
#  'sleepiness': {'meningitis'},
#  'easy_bruising': {'liver_cirrhosis'},
#  'leg_swelling': {'liver_cirrhosis'},
#  'spider_like_blood_vessels_on_skin': {'liver_cirrhosis'},
#  'dull_head_pain': {'tension_headache'},
#  'pressure_around_forehead': {'tension_headache'},
#  'tight_neck_or_shoulders': {'tension_headache'},
#  'scalp_tenderness': {'tension_headache'},
#  'trouble_concentrating': {'adhd', 'tension_headache'},
#  'delayed_speech': {'autism_spectrum_disorder'},
#  'difficulty_with_social_interaction': {'autism_spectrum_disorder'},
#  'repetitive_behaviors': {'autism_spectrum_disorder', 'ocd'},
#  'poor_eye_contact': {'autism_spectrum_disorder'},
#  'limited_interests': {'autism_spectrum_disorder'},
#  'sensitivity_to_light_or_sound': {'autism_spectrum_disorder'},
#  'inattention': {'adhd'},
#  'hyperactivity': {'adhd'},
#  'impulsivity': {'adhd'},
#  'fidgeting': {'adhd'},
#  'forgetfulness': {'adhd'},
#  'obsessive_thoughts': {'ocd'},
#  'anxiety': {'ocd'},
#  'ritualistic_behavior': {'ocd'},
#  'compulsive_cleaning': {'ocd'},
#  'fear_of_contamination': {'ocd'},
#  'koplik_spots': {'measles'},
#  'swollen_salivary_glands': {'mumps'},
#  'pain_while_chewing': {'mumps'},
#  'low_grade_fever': {'rubella'},
#  'conjunctivitis': {'rubella'},
#  'itchy_rash': {'chickenpox'},
#  'blister_like_lesions': {'chickenpox'},
#  'tiredness': {'chickenpox'},
#  'swelling_in_legs': {'congestive_heart_failure'},
#  'rapid_weight_gain': {'congestive_heart_failure'},
#  'irregular_heartbeat': {'congestive_heart_failure'},
#  'palpitations': {'arrhythmia'},
#  'chest_discomfort': {'arrhythmia'},
#  'fainting': {'arrhythmia'},
#  'sudden_joint_pain': {'gout'},
#  'warmth_in_joint': {'gout'},
#  'limited_joint_movement': {'gout'},
#  'tenderness_in_big_toe': {'gout'},
#  'widespread_pain': {'fibromyalgia'},
#  'cognitive_difficulties': {'fibromyalgia'},
#  'sensitivity_to_touch': {'fibromyalgia'},
#  'irregular_periods': {'cushing_syndrome', 'polycystic_ovary_syndrome'},
#  'acne': {'polycystic_ovary_syndrome'},
#  'excess_facial_hair': {'polycystic_ovary_syndrome'},
#  'ovarian_cysts': {'polycystic_ovary_syndrome'},
#  'infertility': {'polycystic_ovary_syndrome'},
#  'moon_face': {'cushing_syndrome'},
#  'buffalo_hump': {'cushing_syndrome'},
#  'purple_stretch_marks': {'cushing_syndrome'},
#  'thin_skin': {'cushing_syndrome'},
#  'low_blood_pressure': {'addison_disease'},
#  'darkening_of_skin': {'addison_disease'},
#  'salt_craving': {'addison_disease'}}

# %%
examples = []
for symptom, diseases in symptom_to_diseases.items():
        example = {
            "input": f"Diagnose the disease based on symptoms: \n Symptoms: {symptom.replace('_', ' ')}",
            "output": "Possible diseases: " + ", ".join(sorted(diseases))
        }
        examples.append(example)

# %%
examples
# Out:
# [{'input': 'Diagnose the disease based on symptoms: \n Symptoms: itching',
#   'output': 'Possible diseases: allergy, chronic_cholestasis, drug_reaction, fungal_infection, hepatitis_a, hepatitis_b, hepatitis_c, impetigo, jaundice, liver_cirrhosis, psoriasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: skin rash',
#   'output': 'Possible diseases: aids, allergy, drug_reaction, fungal_infection, impetigo, lupus, measles'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: nodular lesions',
#   'output': 'Possible diseases: fungal_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: skin eruptions',
#   'output': 'Possible diseases: fungal_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: discolored patches',
#   'output': 'Possible diseases: fungal_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: scaling',
#   'output': 'Possible diseases: fungal_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: redness',
#   'output': 'Possible diseases: fungal_infection, gout'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: cracked skin',
#   'output': 'Possible diseases: fungal_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: peeling skin',
#   'output': 'Possible diseases: fungal_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sneezing',
#   'output': 'Possible diseases: allergy, common_cold'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: runny nose',
#   'output': 'Possible diseases: allergy, measles'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: nasal congestion',
#   'output': 'Possible diseases: allergy'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: itchy eyes',
#   'output': 'Possible diseases: allergy'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: watery eyes',
#   'output': 'Possible diseases: allergy'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: hives',
#   'output': 'Possible diseases: allergy, drug_reaction'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: swelling',
#   'output': 'Possible diseases: allergy, drug_reaction, gout'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: shortness of breath',
#   'output': 'Possible diseases: aids, allergy, anemia, arrhythmia, bronchial_asthma, chronic_obstructive_pulmonary_disease, congestive_heart_failure, coronary_artery_disease, covid_19, drug_reaction, hypertension, pneumonia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: wheezing',
#   'output': 'Possible diseases: allergy, bronchial_asthma, chronic_obstructive_pulmonary_disease, drug_reaction'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: coughing',
#   'output': 'Possible diseases: allergy, bronchial_asthma'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: red eyes',
#   'output': 'Possible diseases: allergy, measles'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: heartburn',
#   'output': 'Possible diseases: GERD, peptic_ulcer_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: chest pain',
#   'output': 'Possible diseases: GERD, anemia, congestive_heart_failure, coronary_artery_disease, hypertension, lupus, pneumonia, tuberculosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: regurgitation',
#   'output': 'Possible diseases: GERD'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: acidic taste in mouth',
#   'output': 'Possible diseases: GERD'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: difficulty swallowing',
#   'output': 'Possible diseases: GERD, paralysis_(brain_hemorrhage)'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: chronic cough',
#   'output': 'Possible diseases: GERD, chronic_obstructive_pulmonary_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sore throat',
#   'output': 'Possible diseases: GERD, common_cold, covid_19, influenza'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: hoarseness',
#   'output': 'Possible diseases: GERD, hypothyroidism'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sensation of lump in throat',
#   'output': 'Possible diseases: GERD'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: nausea',
#   'output': 'Possible diseases: GERD, addison_disease, appendicitis, chronic_cholestasis, coronary_artery_disease, dengue, drug_reaction, gallstones, gastroenteritis, hepatitis_a, hepatitis_b, hepatitis_c, hepatitis_e, jaundice, kidney_stones, liver_cirrhosis, malaria, meningitis, migraine, pancreatitis, peptic_ulcer_disease, pneumonia, typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: bad breath',
#   'output': 'Possible diseases: GERD'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: fatigue',
#   'output': 'Possible diseases: addison_disease, anemia, anxiety_disorder, arrhythmia, arthritis, bronchial_asthma, chronic_cholestasis, chronic_obstructive_pulmonary_disease, congestive_heart_failure, coronary_artery_disease, covid_19, dengue, depression, diabetes_mellitus, drug_reaction, fibromyalgia, hepatitis_a, hepatitis_b, hepatitis_c, hepatitis_e, hypertension, hyperthyroidism, hypothyroidism, influenza, jaundice, liver_cirrhosis, lupus, malaria, migraine, multiple_sclerosis, pneumonia, rheumatoid_arthritis, tuberculosis, typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: jaundice',
#   'output': 'Possible diseases: chronic_cholestasis, gallstones, hepatitis_a, hepatitis_b, hepatitis_c, hepatitis_e, liver_cirrhosis, malaria'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: dark urine',
#   'output': 'Possible diseases: chronic_cholestasis, hepatitis_a, hepatitis_b, hepatitis_c, hepatitis_e, jaundice'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pale stools',
#   'output': 'Possible diseases: chronic_cholestasis, jaundice'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: abdominal pain',
#   'output': 'Possible diseases: addison_disease, appendicitis, chronic_cholestasis, dengue, drug_reaction, gastroenteritis, hepatitis_a, hepatitis_b, hepatitis_c, hepatitis_e, jaundice, malaria, typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: loss of appetite',
#   'output': 'Possible diseases: appendicitis, chickenpox, chronic_cholestasis, gastroenteritis, hepatitis_a, hepatitis_b, hepatitis_c, hepatitis_e, jaundice, liver_cirrhosis, mumps, peptic_ulcer_disease, rheumatoid_arthritis, tuberculosis, typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: weight loss',
#   'output': 'Possible diseases: addison_disease, chronic_cholestasis, hyperthyroidism, jaundice, peptic_ulcer_disease, tuberculosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: dry skin',
#   'output': 'Possible diseases: chronic_cholestasis, hypothyroidism, psoriasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: bone pain',
#   'output': 'Possible diseases: chronic_cholestasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: fever',
#   'output': 'Possible diseases: aids, appendicitis, chickenpox, covid_19, drug_reaction, gallstones, gastroenteritis, hepatitis_a, hepatitis_b, hepatitis_c, hepatitis_e, influenza, lupus, malaria, meningitis, mumps, pancreatitis, pneumonia, rheumatoid_arthritis, tuberculosis, urinary_tract_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: chills',
#   'output': 'Possible diseases: drug_reaction, influenza, malaria'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: vomiting',
#   'output': 'Possible diseases: appendicitis, dengue, drug_reaction, gallstones, gastroenteritis, hepatitis_a, hepatitis_b, hepatitis_c, hepatitis_e, jaundice, kidney_stones, malaria, meningitis, migraine, pancreatitis, peptic_ulcer_disease, pneumonia, typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: joint pain',
#   'output': 'Possible diseases: arthritis, drug_reaction, hepatitis_b, hepatitis_c, lupus, rheumatoid_arthritis, rubella'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: yellowing of skin or eyes',
#   'output': 'Possible diseases: drug_reaction'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: eosinophilia',
#   'output': 'Possible diseases: drug_reaction'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: anaphylaxis',
#   'output': 'Possible diseases: drug_reaction'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: burning stomach pain',
#   'output': 'Possible diseases: peptic_ulcer_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: bloating',
#   'output': 'Possible diseases: gastroenteritis, peptic_ulcer_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: indigestion',
#   'output': 'Possible diseases: peptic_ulcer_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: bloody or black stools',
#   'output': 'Possible diseases: peptic_ulcer_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: feeling of fullness',
#   'output': 'Possible diseases: peptic_ulcer_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: belching',
#   'output': 'Possible diseases: peptic_ulcer_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: gastritis',
#   'output': 'Possible diseases: peptic_ulcer_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: anemia',
#   'output': 'Possible diseases: malaria, peptic_ulcer_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: unexplained weight loss',
#   'output': 'Possible diseases: aids, diabetes_mellitus'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: night sweats',
#   'output': 'Possible diseases: aids, tuberculosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: chronic fatigue',
#   'output': 'Possible diseases: aids'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: swollen lymph nodes',
#   'output': 'Possible diseases: aids, impetigo, rubella'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: frequent infections',
#   'output': 'Possible diseases: aids, diabetes_mellitus'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: diarrhea',
#   'output': 'Possible diseases: aids, covid_19, dengue, gastroenteritis, malaria'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: persistent cough',
#   'output': 'Possible diseases: aids, congestive_heart_failure, tuberculosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: oral candidiasis',
#   'output': 'Possible diseases: aids'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pneumonia',
#   'output': 'Possible diseases: aids'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: lesions in mouth or genitals',
#   'output': 'Possible diseases: aids'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: neurological symptoms',
#   'output': 'Possible diseases: aids'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: memory loss',
#   'output': 'Possible diseases: aids, alzheimers_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: confusion',
#   'output': 'Possible diseases: aids, liver_cirrhosis, meningitis, paralysis_(brain_hemorrhage), pneumonia, stroke'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: cramps',
#   'output': 'Possible diseases: gastroenteritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: headache',
#   'output': 'Possible diseases: anemia, chickenpox, common_cold, covid_19, gastroenteritis, hypertension, influenza, malaria, mumps, rubella, typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: dehydration',
#   'output': 'Possible diseases: gastroenteritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: bloody stools',
#   'output': 'Possible diseases: gastroenteritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: chest tightness',
#   'output': 'Possible diseases: bronchial_asthma, chronic_obstructive_pulmonary_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: difficulty breathing',
#   'output': 'Possible diseases: bronchial_asthma, paralysis_(brain_hemorrhage)'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: rapid breathing',
#   'output': 'Possible diseases: bronchial_asthma, pneumonia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: difficulty talking',
#   'output': 'Possible diseases: bronchial_asthma'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sweating',
#   'output': 'Possible diseases: bronchial_asthma, coronary_artery_disease, hyperthyroidism, malaria, pneumonia, typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: restlessness',
#   'output': 'Possible diseases: anxiety_disorder, bronchial_asthma'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: severe headache',
#   'output': 'Possible diseases: dengue, meningitis, migraine, paralysis_(brain_hemorrhage), stroke'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sensitivity to light',
#   'output': 'Possible diseases: meningitis, migraine'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sensitivity to sound',
#   'output': 'Possible diseases: migraine'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: blurred vision',
#   'output': 'Possible diseases: diabetes_mellitus, migraine'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: aura',
#   'output': 'Possible diseases: epilepsy, migraine'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: throbbing pain',
#   'output': 'Possible diseases: migraine'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: unilateral headache',
#   'output': 'Possible diseases: migraine'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: dizziness',
#   'output': 'Possible diseases: anemia, arrhythmia, coronary_artery_disease, hypertension, migraine, multiple_sclerosis, paralysis_(brain_hemorrhage), stroke'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: difficulty concentrating',
#   'output': 'Possible diseases: anxiety_disorder, depression, migraine'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: neck pain',
#   'output': 'Possible diseases: cervical_spondylosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: stiffness in neck',
#   'output': 'Possible diseases: cervical_spondylosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: headaches',
#   'output': 'Possible diseases: cervical_spondylosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: shoulder pain',
#   'output': 'Possible diseases: cervical_spondylosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: numbness or tingling in arms',
#   'output': 'Possible diseases: cervical_spondylosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: muscle weakness',
#   'output': 'Possible diseases: arthritis, cervical_spondylosis, cushing_syndrome, multiple_sclerosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: loss of balance',
#   'output': 'Possible diseases: cervical_spondylosis, paralysis_(brain_hemorrhage), stroke'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: radiating pain in arms or hands',
#   'output': 'Possible diseases: cervical_spondylosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: reduced range of motion in neck',
#   'output': 'Possible diseases: cervical_spondylosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pain when turning head',
#   'output': 'Possible diseases: cervical_spondylosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sudden loss of movement',
#   'output': 'Possible diseases: paralysis_(brain_hemorrhage)'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: weakness on one side of body',
#   'output': 'Possible diseases: paralysis_(brain_hemorrhage)'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: numbness',
#   'output': 'Possible diseases: paralysis_(brain_hemorrhage)'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: vision problems',
#   'output': 'Possible diseases: multiple_sclerosis, paralysis_(brain_hemorrhage), stroke'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: difficulty speaking',
#   'output': 'Possible diseases: paralysis_(brain_hemorrhage)'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: seizures',
#   'output': 'Possible diseases: meningitis, paralysis_(brain_hemorrhage)'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: neck stiffness',
#   'output': 'Possible diseases: paralysis_(brain_hemorrhage)'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: yellowing of skin',
#   'output': 'Possible diseases: jaundice'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: yellowing of eyes',
#   'output': 'Possible diseases: jaundice'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: swelling in legs or abdomen',
#   'output': 'Possible diseases: hepatitis_c, jaundice'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: muscle pain',
#   'output': 'Possible diseases: malaria'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: cough',
#   'output': 'Possible diseases: common_cold, covid_19, influenza, malaria, measles, pneumonia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: high fever',
#   'output': 'Possible diseases: dengue, measles, typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pain behind eyes',
#   'output': 'Possible diseases: dengue'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: muscle and joint pain',
#   'output': 'Possible diseases: dengue, hepatitis_a'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: rash',
#   'output': 'Possible diseases: dengue, rubella, typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: skin bleeding',
#   'output': 'Possible diseases: dengue'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: nosebleeds',
#   'output': 'Possible diseases: dengue, hypertension'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: gum bleeding',
#   'output': 'Possible diseases: dengue'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: low white blood cell count',
#   'output': 'Possible diseases: dengue'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: weakness',
#   'output': 'Possible diseases: anemia, typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: diarrhea or constipation',
#   'output': 'Possible diseases: typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: dry cough',
#   'output': 'Possible diseases: typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: enlarged spleen or liver',
#   'output': 'Possible diseases: typhoid'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: light colored stools',
#   'output': 'Possible diseases: hepatitis_a, hepatitis_b, hepatitis_c, hepatitis_e'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: muscle aches',
#   'output': 'Possible diseases: hepatitis_b, hepatitis_c, influenza, mumps, pneumonia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: elevated liver enzyme levels',
#   'output': 'Possible diseases: hepatitis_c'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: shaking chills',
#   'output': 'Possible diseases: pneumonia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: blue tinged skin',
#   'output': 'Possible diseases: pneumonia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: swelling in joints',
#   'output': 'Possible diseases: arthritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: stiffness',
#   'output': 'Possible diseases: arthritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: reduced range of motion',
#   'output': 'Possible diseases: arthritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: warmth in joints',
#   'output': 'Possible diseases: arthritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: redness in joints',
#   'output': 'Possible diseases: arthritis, rheumatoid_arthritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: tenderness in joints',
#   'output': 'Possible diseases: arthritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: difficulty moving joints',
#   'output': 'Possible diseases: arthritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: red patchy skin',
#   'output': 'Possible diseases: psoriasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: scaly skin',
#   'output': 'Possible diseases: psoriasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: painful skin',
#   'output': 'Possible diseases: psoriasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: cracked skin that may bleed',
#   'output': 'Possible diseases: psoriasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: swollen joints',
#   'output': 'Possible diseases: psoriasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: thickened nails',
#   'output': 'Possible diseases: psoriasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: flaking scales on the skin',
#   'output': 'Possible diseases: psoriasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: burning sensation on skin',
#   'output': 'Possible diseases: psoriasis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: red sores',
#   'output': 'Possible diseases: impetigo'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: fluid filled blisters',
#   'output': 'Possible diseases: impetigo'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: honey colored crusts',
#   'output': 'Possible diseases: impetigo'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: painful sores',
#   'output': 'Possible diseases: impetigo'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: spreading skin lesions',
#   'output': 'Possible diseases: impetigo'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: mild fever',
#   'output': 'Possible diseases: impetigo'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: increased thirst',
#   'output': 'Possible diseases: diabetes_mellitus'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: frequent urination',
#   'output': 'Possible diseases: diabetes_mellitus, kidney_stones, urinary_tract_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: extreme hunger',
#   'output': 'Possible diseases: diabetes_mellitus'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: slow healing sores',
#   'output': 'Possible diseases: diabetes_mellitus'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: visual disturbances',
#   'output': 'Possible diseases: hypertension'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pain in arms or back',
#   'output': 'Possible diseases: coronary_artery_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sudden numbness or weakness',
#   'output': 'Possible diseases: stroke'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: trouble speaking or understanding',
#   'output': 'Possible diseases: stroke'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: coughing up blood',
#   'output': 'Possible diseases: tuberculosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: runny or stuffy nose',
#   'output': 'Possible diseases: common_cold, influenza'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sweats',
#   'output': 'Possible diseases: influenza'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: mild fatigue',
#   'output': 'Possible diseases: common_cold'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: low-grade fever',
#   'output': 'Possible diseases: common_cold'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: muscle or body aches',
#   'output': 'Possible diseases: covid_19'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: new loss of taste or smell',
#   'output': 'Possible diseases: covid_19'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: congestion or runny nose',
#   'output': 'Possible diseases: covid_19'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: nausea or vomiting',
#   'output': 'Possible diseases: covid_19'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: frequent respiratory infections',
#   'output': 'Possible diseases: chronic_obstructive_pulmonary_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: swelling in ankles legs or feet',
#   'output': 'Possible diseases: chronic_obstructive_pulmonary_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: recurrent seizures',
#   'output': 'Possible diseases: epilepsy'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: loss of consciousness',
#   'output': 'Possible diseases: epilepsy'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: muscle stiffness',
#   'output': 'Possible diseases: epilepsy'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: jerking movements',
#   'output': 'Possible diseases: epilepsy'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: confusion after seizure',
#   'output': 'Possible diseases: epilepsy'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: staring spells',
#   'output': 'Possible diseases: epilepsy'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: tremors',
#   'output': 'Possible diseases: hyperthyroidism, parkinsons_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: muscle rigidity',
#   'output': 'Possible diseases: parkinsons_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: bradykinesia',
#   'output': 'Possible diseases: parkinsons_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: postural instability',
#   'output': 'Possible diseases: parkinsons_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: slurred speech',
#   'output': 'Possible diseases: parkinsons_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: writing changes',
#   'output': 'Possible diseases: parkinsons_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: depression',
#   'output': 'Possible diseases: fibromyalgia, hypothyroidism, parkinsons_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sleep disturbances',
#   'output': 'Possible diseases: anxiety_disorder, bipolar_disorder, depression, fibromyalgia, parkinsons_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: difficulty planning or solving problems',
#   'output': 'Possible diseases: alzheimers_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: confusion with time or place',
#   'output': 'Possible diseases: alzheimers_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: trouble understanding visual images',
#   'output': 'Possible diseases: alzheimers_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: new problems with words in speaking or writing',
#   'output': 'Possible diseases: alzheimers_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: misplacing things',
#   'output': 'Possible diseases: alzheimers_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: decreased judgment',
#   'output': 'Possible diseases: alzheimers_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: withdrawal from work or social activities',
#   'output': 'Possible diseases: alzheimers_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: changes in mood or personality',
#   'output': 'Possible diseases: alzheimers_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: persistent sadness',
#   'output': 'Possible diseases: depression'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: loss of interest in activities',
#   'output': 'Possible diseases: depression'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: appetite changes',
#   'output': 'Possible diseases: depression'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: feelings of worthlessness',
#   'output': 'Possible diseases: depression'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: thoughts of death or suicide',
#   'output': 'Possible diseases: depression'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: excessive worry',
#   'output': 'Possible diseases: anxiety_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: irritability',
#   'output': 'Possible diseases: anxiety_disorder, tension_headache'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: muscle tension',
#   'output': 'Possible diseases: anxiety_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: panic attacks',
#   'output': 'Possible diseases: anxiety_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: extreme mood swings',
#   'output': 'Possible diseases: bipolar_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: manic episodes',
#   'output': 'Possible diseases: bipolar_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: depressive episodes',
#   'output': 'Possible diseases: bipolar_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: impulsive behaviors',
#   'output': 'Possible diseases: bipolar_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: racing thoughts',
#   'output': 'Possible diseases: bipolar_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: increased activity levels',
#   'output': 'Possible diseases: bipolar_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: weight gain',
#   'output': 'Possible diseases: cushing_syndrome, hypothyroidism, polycystic_ovary_syndrome'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: cold intolerance',
#   'output': 'Possible diseases: hypothyroidism'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: constipation',
#   'output': 'Possible diseases: hypothyroidism'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: slow heart rate',
#   'output': 'Possible diseases: hypothyroidism'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: memory problems',
#   'output': 'Possible diseases: hypothyroidism, multiple_sclerosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: puffy face',
#   'output': 'Possible diseases: hypothyroidism'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: rapid heartbeat',
#   'output': 'Possible diseases: hyperthyroidism, pancreatitis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: nervousness',
#   'output': 'Possible diseases: hyperthyroidism'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: heat intolerance',
#   'output': 'Possible diseases: hyperthyroidism'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: frequent bowel movements',
#   'output': 'Possible diseases: hyperthyroidism'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sleep difficulty',
#   'output': 'Possible diseases: hyperthyroidism'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: goiter',
#   'output': 'Possible diseases: hyperthyroidism'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: hair loss',
#   'output': 'Possible diseases: lupus'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: photosensitivity',
#   'output': 'Possible diseases: lupus'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: mouth ulcers',
#   'output': 'Possible diseases: lupus'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: kidney problems',
#   'output': 'Possible diseases: lupus'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: swelling in legs or eyes',
#   'output': 'Possible diseases: lupus'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: numbness or tingling',
#   'output': 'Possible diseases: multiple_sclerosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: balance problems',
#   'output': 'Possible diseases: multiple_sclerosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: bladder issues',
#   'output': 'Possible diseases: multiple_sclerosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: difficulty walking',
#   'output': 'Possible diseases: multiple_sclerosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: joint swelling',
#   'output': 'Possible diseases: rheumatoid_arthritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: morning stiffness',
#   'output': 'Possible diseases: rheumatoid_arthritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: symmetrical joint involvement',
#   'output': 'Possible diseases: rheumatoid_arthritis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: back pain',
#   'output': 'Possible diseases: osteoporosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: loss of height',
#   'output': 'Possible diseases: osteoporosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: stooped posture',
#   'output': 'Possible diseases: osteoporosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: easy bone fractures',
#   'output': 'Possible diseases: osteoporosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: brittle bones',
#   'output': 'Possible diseases: osteoporosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: limited mobility',
#   'output': 'Possible diseases: osteoporosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pale skin',
#   'output': 'Possible diseases: anemia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: cold hands and feet',
#   'output': 'Possible diseases: anemia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pain in lower right abdomen',
#   'output': 'Possible diseases: appendicitis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: constipation or diarrhea',
#   'output': 'Possible diseases: appendicitis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: abdominal swelling',
#   'output': 'Possible diseases: appendicitis, liver_cirrhosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: burning sensation during urination',
#   'output': 'Possible diseases: urinary_tract_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: cloudy urine',
#   'output': 'Possible diseases: kidney_stones, urinary_tract_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: strong urine odor',
#   'output': 'Possible diseases: urinary_tract_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pelvic pain',
#   'output': 'Possible diseases: urinary_tract_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: blood in urine',
#   'output': 'Possible diseases: kidney_stones, urinary_tract_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: lower abdominal pain',
#   'output': 'Possible diseases: urinary_tract_infection'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: severe flank pain',
#   'output': 'Possible diseases: kidney_stones'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pain during urination',
#   'output': 'Possible diseases: kidney_stones'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: foul smelling urine',
#   'output': 'Possible diseases: kidney_stones'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sudden abdominal pain',
#   'output': 'Possible diseases: gallstones'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pain in right upper abdomen',
#   'output': 'Possible diseases: gallstones'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: back pain between shoulders',
#   'output': 'Possible diseases: gallstones'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pain after eating fatty foods',
#   'output': 'Possible diseases: gallstones'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: upper abdominal pain',
#   'output': 'Possible diseases: pancreatitis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: abdominal pain that radiates to back',
#   'output': 'Possible diseases: pancreatitis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: swollen abdomen',
#   'output': 'Possible diseases: pancreatitis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: tenderness in abdomen',
#   'output': 'Possible diseases: pancreatitis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: stiff neck',
#   'output': 'Possible diseases: meningitis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sleepiness',
#   'output': 'Possible diseases: meningitis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: easy bruising',
#   'output': 'Possible diseases: liver_cirrhosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: leg swelling',
#   'output': 'Possible diseases: liver_cirrhosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: spider like blood vessels on skin',
#   'output': 'Possible diseases: liver_cirrhosis'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: dull head pain',
#   'output': 'Possible diseases: tension_headache'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pressure around forehead',
#   'output': 'Possible diseases: tension_headache'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: tight neck or shoulders',
#   'output': 'Possible diseases: tension_headache'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: scalp tenderness',
#   'output': 'Possible diseases: tension_headache'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: trouble concentrating',
#   'output': 'Possible diseases: adhd, tension_headache'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: delayed speech',
#   'output': 'Possible diseases: autism_spectrum_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: difficulty with social interaction',
#   'output': 'Possible diseases: autism_spectrum_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: repetitive behaviors',
#   'output': 'Possible diseases: autism_spectrum_disorder, ocd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: poor eye contact',
#   'output': 'Possible diseases: autism_spectrum_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: limited interests',
#   'output': 'Possible diseases: autism_spectrum_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sensitivity to light or sound',
#   'output': 'Possible diseases: autism_spectrum_disorder'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: inattention',
#   'output': 'Possible diseases: adhd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: hyperactivity',
#   'output': 'Possible diseases: adhd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: impulsivity',
#   'output': 'Possible diseases: adhd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: fidgeting',
#   'output': 'Possible diseases: adhd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: forgetfulness',
#   'output': 'Possible diseases: adhd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: obsessive thoughts',
#   'output': 'Possible diseases: ocd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: anxiety',
#   'output': 'Possible diseases: ocd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: ritualistic behavior',
#   'output': 'Possible diseases: ocd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: compulsive cleaning',
#   'output': 'Possible diseases: ocd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: fear of contamination',
#   'output': 'Possible diseases: ocd'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: koplik spots',
#   'output': 'Possible diseases: measles'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: swollen salivary glands',
#   'output': 'Possible diseases: mumps'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: pain while chewing',
#   'output': 'Possible diseases: mumps'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: low grade fever',
#   'output': 'Possible diseases: rubella'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: conjunctivitis',
#   'output': 'Possible diseases: rubella'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: itchy rash',
#   'output': 'Possible diseases: chickenpox'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: blister like lesions',
#   'output': 'Possible diseases: chickenpox'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: tiredness',
#   'output': 'Possible diseases: chickenpox'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: swelling in legs',
#   'output': 'Possible diseases: congestive_heart_failure'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: rapid weight gain',
#   'output': 'Possible diseases: congestive_heart_failure'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: irregular heartbeat',
#   'output': 'Possible diseases: congestive_heart_failure'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: palpitations',
#   'output': 'Possible diseases: arrhythmia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: chest discomfort',
#   'output': 'Possible diseases: arrhythmia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: fainting',
#   'output': 'Possible diseases: arrhythmia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sudden joint pain',
#   'output': 'Possible diseases: gout'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: warmth in joint',
#   'output': 'Possible diseases: gout'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: limited joint movement',
#   'output': 'Possible diseases: gout'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: tenderness in big toe',
#   'output': 'Possible diseases: gout'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: widespread pain',
#   'output': 'Possible diseases: fibromyalgia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: cognitive difficulties',
#   'output': 'Possible diseases: fibromyalgia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: sensitivity to touch',
#   'output': 'Possible diseases: fibromyalgia'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: irregular periods',
#   'output': 'Possible diseases: cushing_syndrome, polycystic_ovary_syndrome'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: acne',
#   'output': 'Possible diseases: polycystic_ovary_syndrome'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: excess facial hair',
#   'output': 'Possible diseases: polycystic_ovary_syndrome'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: ovarian cysts',
#   'output': 'Possible diseases: polycystic_ovary_syndrome'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: infertility',
#   'output': 'Possible diseases: polycystic_ovary_syndrome'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: moon face',
#   'output': 'Possible diseases: cushing_syndrome'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: buffalo hump',
#   'output': 'Possible diseases: cushing_syndrome'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: purple stretch marks',
#   'output': 'Possible diseases: cushing_syndrome'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: thin skin',
#   'output': 'Possible diseases: cushing_syndrome'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: low blood pressure',
#   'output': 'Possible diseases: addison_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: darkening of skin',
#   'output': 'Possible diseases: addison_disease'},
#  {'input': 'Diagnose the disease based on symptoms: \n Symptoms: salt craving',
#   'output': 'Possible diseases: addison_disease'}]

# %%
def preprocess_data(examples):
    inputs = examples["input"]
    targets = examples["output"]

    # Tokenize inputs
    model_inputs = tokenizer(inputs, max_length=128, truncation=True, padding="max_length")

    # Tokenize targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=128, truncation=True, padding="max_length")

    model_inputs["labels"] = labels["input_ids"]

    # For decoder inputs
    decoder_inputs = tokenizer(targets, max_length=128, truncation=True, padding="max_length")
    model_inputs["decoder_input_ids"] = decoder_inputs["input_ids"]

    return model_inputs

# %%
from sklearn.model_selection import train_test_split

# Split into train (80%) and temp (20%)
train_examples, temp_examples = train_test_split(examples, test_size=0.2, random_state=42)

# Split temp into validation (10%) and test (10%)
val_examples, test_examples = train_test_split(temp_examples, test_size=0.5, random_state=42)

# %%
import tensorflow as tf

from datasets import Dataset

train_dataset = Dataset.from_list(train_examples)
val_dataset = Dataset.from_list(val_examples)

train_dataset = train_dataset.map(preprocess_data, batched=True)
val_dataset = val_dataset.map(preprocess_data, batched=True)


train_dataset = train_dataset.to_tf_dataset(
    columns=['input_ids', 'attention_mask', 'decoder_input_ids'],
    label_cols=['labels'],
    shuffle=True,
    batch_size=8,
    collate_fn=None
)
val_dataset = val_dataset.to_tf_dataset(
    columns=['input_ids', 'attention_mask', 'decoder_input_ids'],
    label_cols=['labels'],
    shuffle=True,
    batch_size=8,
    collate_fn=None
)
# Out:
# Map:   0%|          | 0/251 [00:00<?, ? examples/s]
# Map:   0%|          | 0/31 [00:00<?, ? examples/s]
# C:\Users\asus\AppData\Roaming\Python\Python312\site-packages\datasets\arrow_dataset.py:400: FutureWarning: The output of `to_tf_dataset` will change when a passing single element list for `labels` or `columns` in the next datasets version. To return a tuple structure rather than dict, pass a single string.
# Old behaviour: columns=['a'], labels=['labels'] -> (tf.Tensor, tf.Tensor)
#              : columns='a', labels='labels' -> (tf.Tensor, tf.Tensor)
# New behaviour: columns=['a'],labels=['labels'] -> ({'a': tf.Tensor}, {'labels': tf.Tensor})
#              : columns='a', labels='labels' -> (tf.Tensor, tf.Tensor)
#   warnings.warn(

# %%
test_dataset = Dataset.from_list(test_examples)

test_dataset = test_dataset.map(preprocess_data, batched=True)

test_dataset = test_dataset.to_tf_dataset(
    columns=['input_ids', 'attention_mask', 'decoder_input_ids'],
    label_cols=['labels'],
    shuffle=True,
    batch_size=8,
    collate_fn=None
)
# Out:
# Map:   0%|          | 0/32 [00:00<?, ? examples/s]

# %%
model.summary()
# Out:
# Model: "tft5_for_conditional_generation_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  shared (Embedding)          multiple                  32899072
#
#  encoder (TFT5MainLayer)     multiple                  341231104
#
#  decoder (TFT5MainLayer)     multiple                  441918976
#
#  lm_head (Dense)             multiple                  32899072
#
# =================================================================
# Total params: 783150080 (-1162366976.00 Byte)
# Trainable params: 783150080 (-1162366976.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Freeze the LLM layer
model.get_layer("shared").trainable = False
model.get_layer("encoder").trainable = False
model.get_layer("decoder").trainable = False

# %%
model.summary()
# Out:
# Model: "tft5_for_conditional_generation_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  shared (Embedding)          multiple                  32899072
#
#  encoder (TFT5MainLayer)     multiple                  341231104
#
#  decoder (TFT5MainLayer)     multiple                  441918976
#
#  lm_head (Dense)             multiple                  32899072
#
# =================================================================
# Total params: 783150080 (-1162366976.00 Byte)
# Trainable params: 32899072 (125.50 MB)
# Non-trainable params: 750251008 (-1293963264.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True))

# Train the model
model.fit(train_dataset, validation_data=val_dataset, epochs=3)
# Out:
# WARNING:tensorflow:From C:\Users\asus\AppData\Roaming\Python\Python312\site-packages\tf_keras\src\optimizers\__init__.py:317: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/3
# WARNING:tensorflow:From C:\Users\asus\AppData\Roaming\Python\Python312\site-packages\tf_keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 32/32 [==============================] - 203s 5s/step - loss: 33.6511 - val_loss: 32.1481
# Epoch 2/3
# 32/32 [==============================] - 156s 5s/step - loss: 29.1294 - val_loss: 27.3696
# Epoch 3/3
# 32/32 [==============================] - 2280s 73s/step - loss: 24.9355 - val_loss: 22.7929

# %%
def diagnose(inputs):
    outputs = model.generate(inputs[0]["input_ids"], max_length=128, num_beams=4, early_stopping=True)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)


for batch in test_dataset.take(5):
    diagnosed = diagnose(batch)
    print(f"Input: {tokenizer.decode(batch[0]['input_ids'][0], skip_special_tokens=True)}")
    print(f"Reference: {tokenizer.decode(batch[1][0], skip_special_tokens=True)}")
    print(f"diagnosed: {diagnosed}")
    print()
# Out:
# Input: Symptoms: radiating pain in arms or hands
# Reference: Possible diseases: cervical_spondylosis
# diagnosed: swollen glands
#
# Input: Symptoms: tremors
# Reference: Possible diseases: hyperthyroidism, parkinsons_disease
# diagnosed: tremors
#
# Input: Symptoms: burning sensation during urination
# Reference: Possible diseases: urinary_tract_infection
# diagnosed: urinary tract infection
#
# Input: Symptoms: muscle and joint pain
# Reference: Possible diseases: dengue, hepatitis_a
# diagnosed: spondylosis
